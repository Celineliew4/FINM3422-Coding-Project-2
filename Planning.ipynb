# %% [markdown]
# **Monday discussion and tasks**
#
# - figuring out valuation method for option type, valuation method used should be different for each of the exotic derivative options
# - defining characteristics of options and how they are unique
# - have a think and research on how discount rates for future cashflows at different maturities are being calculate
# - research what best source instruments to calculate discount factors from

# %% [markdown]
# ## Planning & Things to keep in mind
#
# *delete later on*
#
#
#
#
# **roles**
#
# Celine: Barrier Option
#
# Hafsah: Basket
#
# Leo: European
#
# Albert: American
#
# ## Process -
#
# ### Step 2: Design Class Hierarchy (Object-Oriented Programming)
#
# Start planning your Python classes using inheritance to avoid duplication.
#
# - Base Class: Option
# - Attributes: underlying, strike, expiry, option_type
# - Methods: get_price(), get_delta()
#
# Subclasses:
# - EuropeanOption(Option)
# - AmericanOption(Option)
# - BarrierOption(EuropeanOption)
# - BasketOption(Option)
#
# Also consider a Portfolio class to hold all positions and compute aggregate hedge info.
#
# ### Step 3: Gather Market Data (as of 16 May 2025)
#
# - Prices: Get closing prices for BHP, CBA, WES, CSL, WDS, MQG
# - Volatility: Estimate implied or historical volatility
# - Risk-Free Rates: Build a yield curve (e.g. from government bond yields)
# - Dividends: Estimate future dividend yield for each stock
#
# ### Step 4: Implement Pricing Methods
#
# Each derivative type may require a different method:
#
# - European Options: Black-Scholes
# - American Option: Binomial Tree or Finite Difference
# - Barrier Option: Analytical (if assumptions allow) or Monte Carlo
# - Basket Option: Monte Carlo simulation with correlated asset paths
#
# Ensure you:
#
# - Use correct interest rate discounting
# - Handle dividend yields properly
# - Validate each model with test cases
#
#
# ### Step 5: Implement Hedging Metrics
#
# At a minimum:
# - Delta for each option
# - Aggregate portfolio delta
# - High scoring:
#     - Gamma, Vega (if possible)
#     - Correlation-adjusted basket delta
#
# ### Step 6: Test Each Module
#
# - Create unit tests for each pricing class
# - Validate model outputs against known benchmarks (e.g. market prices or textbook cases)
#
#
# ### Step 7: Build the Jupyter Notebook
#
# - Intro & context
# - Code cells with class definitions
# - Example cells that instantiate and price each trade
# - Output section with prices and hedge info
# - Clean and well-commented code

# %% [markdown]
# ### Celine - Barrier Option
#
# *Main feature*
#
# main feature of barrier exotic options is that the contracts become activated only if the price of the underlying asset reaches a predetermined level.
#
# *other mechanisms*
#
# - A barrier option can expire worthless (knock-out option) should the price of the underlying asset exceed a certain price, thus limiting profit for the option holder and limiting losses for the option writer (seller). The barrier option can be a knock-in option, which means it lacks any value until the moment the underlying asset strikes a particular price.
# - Barrier options are also referred to as path-dependent options since their value fluctuates along with the value of the underlying assets.
